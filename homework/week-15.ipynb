# %% [markdown]
# <a href="https://colab.research.google.com/github/simoneminorr/ds1002-uqa9qp/blob/main/homework/week-15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 15
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL to your notebook for review.

# %% [markdown]
# ## 1. Create Functions (4 pts)
#
# Create two functions in the cells below, according to the prompts given.

# %%
# create a function in R that:
#   1. takes a single integer as an input parameter
#   2. determines whether the integer is even or odd
#   3. returns a character statement "The integer <x> is even" or "The integer <x> is odd" (replace <x> with the actual input provided)
#
# then execute the function twice using two different input values, displaying even and odd results.


evenoddoperator <- function(x) if (x %% 2 ==0) {
  print("x is even")
} else
  print("x is odd")

evenoddoperator(8)
evenoddoperator(11)
# Out:
# [1] "x is even"
# [1] "x is odd"

# %%
# create a function in R that:
#   1. takes 4 integer input parameters
#   2. returns the mean value of the inputs
#   3. has default values for the 4 input parameters, in case they are not provided when the function is called.
#
# then execute the function twice: once where you provide the input values, and once where you do not.

meanoperator <- function(w, x, y, z) {
  mean= (w + x + y + z)/4
if (w != 21)
w <- 21
else if (x != 73)
x <- 73
else if (y != 3)
y <- 3
else (z != 2)
z <- 2
return (mean)}

meanoperator( 4,5,3,2)
meanoperator( 21,73,3,2)
# Out:
# [1] 3.5
# [1] 24.75

# %%
#trying out different things but I am stuck
meanoperator <- function(w, x, y, z) {
  mean= (w + x + y + z)/4
if (w == "")
w <- 21
else if (x == "")
x <- 73
else if (y == "")
y <- 3
else (z == "")
z <- 2
return (mean)}

meanoperator( 4,5,3,2)
meanoperator( 21,73,3,2)
# Out:
# [1] 3.5
# [1] 24.75

# %% [markdown]
# ## 2. Plot Data (4 pts)

# %% [markdown]
# In the cell below, write the code required to plot from the `msleep` sample data set.
#
# 1. Display only animals with body weights of 30 or greater.
# 2. Group the animals by `order`.
# 3. Display the mean `sleep_total` for each group in a bar plot.

# %%
#loading libraries and checking data set
library(tidyverse)
library(ggplot2)
install.packages("gapminder")
library(gapminder)

msleep
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#    name                           genus         vore    order
# 1  Cheetah                        Acinonyx      carni   Carnivora
# 2  Owl monkey                     Aotus         omni    Primates
# 3  Mountain beaver                Aplodontia    herbi   Rodentia
# 4  Greater short-tailed shrew     Blarina       omni    Soricomorpha
# ...

# %%
#listing top 30 body weights
top30msleep <- msleep[msleep$bodywt >30, ]
top30msleep
# Out:
#    name                 genus         vore    order          conservation
# 1  Cheetah              Acinonyx      carni   Carnivora      lc
# 2  Cow                  Bos           herbi   Artiodactyla   domesticated
# 3  Goat                 Capri         herbi   Artiodactyla   lc
# 4  Asian elephant       Elephas       herbi   Proboscidea    en
# 5  Horse                Equus         herbi   Perissodactyla domesticated
# 6  Donkey               Equus         herbi   Perissodactyla domesticated
# 7  Giraffe              Giraffa       herbi   Artiodactyla   cd
# 8  Pilot whale          Globicephalus carni   Cetacea        cd
# 9  Gray seal            Haliochoerus  carni   Carnivora      lc
# 10 Human                Homo          omni    Primates       NA
# 11 African elephant     Loxodonta     herbi   Proboscidea    vu
# 12 Sheep                Ovis          herbi   Artiodactyla   domesticated
# 13 Chimpanzee           Pan           omni    Primates       NA
# ...

# %%
animalsordered <- msleep %>%
  arrange(order)
animalsordered
# Out:
#    name                           genus         vore    order
# 1  Tenrec                         Tenrec        omni    Afrosoricida
# 2  Cow                            Bos           herbi   Artiodactyla
# 3  Roe deer                       Capreolus     herbi   Artiodactyla
# 4  Goat                           Capri         herbi   Artiodactyla
# 5  Giraffe                        Giraffa       herbi   Artiodactyla
# 6  Sheep                          Ovis          herbi   Artiodactyla
# 7  Pig                            Sus           omni    Artiodactyla
# 8  Cheetah                        Acinonyx      carni   Carnivora
# 9  Northern fur seal              Callorhinus   carni   Carnivora
# 10 Dog                            Canis         carni   Carnivora
# 11 Domestic cat                   Felis         carni   Carnivora
# 12 Gray seal                      Haliochoerus  carni   Carnivora
# 13 Tiger                          Panthera      carni   Carnivora
# ...

# %%
#group animals by order
top30ordered <- top30msleep %>%
  arrange(order)
top30ordered
# Out:
#    name                 genus         vore    order          conservation
# 1  Cow                  Bos           herbi   Artiodactyla   domesticated
# 2  Goat                 Capri         herbi   Artiodactyla   lc
# 3  Giraffe              Giraffa       herbi   Artiodactyla   cd
# 4  Sheep                Ovis          herbi   Artiodactyla   domesticated
# 5  Pig                  Sus           omni    Artiodactyla   domesticated
# 6  Cheetah              Acinonyx      carni   Carnivora      lc
# 7  Gray seal            Haliochoerus  carni   Carnivora      lc
# 8  Tiger                Panthera      carni   Carnivora      en
# 9  Jaguar               Panthera      carni   Carnivora      nt
# 10 Lion                 Panthera      carni   Carnivora      vu
# 11 Caspian seal         Phoca         carni   Carnivora      vu
# 12 Pilot whale          Globicephalus carni   Cetacea        cd
# 13 Common porpoise      Phocoena      carni   Cetacea        vu
# ...

# %%
#WRONG OLD CODE
meantop30 <- top30ordered %>%
  group_by(order) %>%
  mutate(meansleep = mean(sleep_total)) %>%
  data.frame()

quickplot(data=meantop30, order, meansleep)
# Out:
# Warning message:
# “`qplot()` was deprecated in ggplot2 3.4.0.”
# plot without title

# %%
#checking to make sure I made the means column
meantop30$meansleep
# Out:
#  [1]  4.820000  4.820000  4.820000  4.820000  4.820000 10.250000 10.250000
#  [8] 10.250000 10.250000 10.250000 10.250000  4.500000  4.500000  4.500000
# [15] 18.100000  3.466667  3.466667  3.466667  8.850000  8.850000  3.600000
# [22]  3.600000

# %%
#CORRECTED histogram [NEW CODE]
meantop30 <- top30ordered %>%
  group_by(order) %>%
  mutate(meansleep = mean(sleep_total)) %>%
  data.frame()

ggplot(top30ordered, aes(x=meantop30$meansleep, fill=order)) + geom_histogram(binwidth = 6)
# Out:
# plot without title

# %%
#WRONG OLD CODE
mean()
ggplot(data= top30ordered,
  mapping= aes(x=, fill=name)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## 3. Clean and Analyze Data Using R (4 pts)
#
# In the cells below use R to perform the following data cleaning steps on this file:
# https://raw.githubusercontent.com/nmagee/ds1002/main/data/social-media-users.csv
#
# 1. Remove any duplicate rows.
# 2. Remove any records where `last_login` or `birthdate` are empty.
# 3. Display only the records with the 10 highest `follower` counts.
# 4. Determine counts of users when grouped by continent.

# %%
#
socialmedia <- read.csv("https://raw.githubusercontent.com/nmagee/ds1002/main/data/social-media-users.csv")

library(dplyr)

# %%
#seeing how many duplicates there are prior to cleaning
nrow(socialmedia[duplicated(socialmedia), ])
social_media <- socialmedia[!duplicated(socialmedia), ]
# Out:
# [1] 318

# %%
#%>% way of removing any NAs
social_media1<- social_media %>% drop_na("last_login")
social_media1<- social_media %>% drop_na("birthdate")
social_media1
# Out:
#     username       full_name            birthdate
# 1   rphettis3      Ruddy Phettis        6/18/1984
# 2   ttotman6       Tamqrah Totman       8/7/1986
# 3   kgrigoryev8    Krishna Grigoryev    5/25/1990
# 4   mchittockb     Myriam Chittock      1/26/1989
# 5   aeasbyd        Alessandra Easby     1/5/1991
# 6   omarusiki      Otha Marusik         12/4/1992
# 7   sspenclayk     Scott Spenclay       12/7/1989
# 8   gklinckl       Georgetta Klinck     7/26/1996
# 9   rhollowm       Riccardo Hollow      1/18/1980
# 10  ddimmockt      Didi Dimmock         5/15/1985
# 11  fpythonu       Franz Python         4/5/1984
# 12  amcclellandz   Annabela McClelland  8/12/1983
# 13  kpietzker11    Keane Pietzker       11/26/1996
# 14  olandreth12    Orsa Landreth        1/10/2000
# 15  clettice14     Cosette Lettice      12/23/1981
# 16  bgribbon1b     Bennie Gribbon       11/12/1984
# 17  lherley1d      Lorianne Herley      11/30/1984
# 18  scleyburn1f    Steward Cleyburn     11/18/1985
# ...

# %%
#removing duplicates from the data set
social_media <- socialmedia[!duplicated(socialmedia), ]
social_media
nrow(social_media[duplicated(social_media), ]) #checking to ensure there are no duplicate rows
# Out:
#      username       full_name            birthdate
# 1    ckippen0       Clevey Kippen        5/1/1991
# 2    tgergler1      Tedi Gergler         10/5/1998
# 3    spomfrett2     Steffie Pomfrett
# 4    rphettis3      Ruddy Phettis        6/18/1984
# 5    ngilcriest4    Nico Gilcriest       10/11/1993
# 6    fhampson5      Farrell Hampson      11/7/1985
# 7    ttotman6       Tamqrah Totman       8/7/1986
# 8    bdennes7       Bonita Dennes
# 9    kgrigoryev8    Krishna Grigoryev    5/25/1990
# 10   mbathoe9       Mallissa Bathoe
# 11   hallensona     Hayward Allenson     3/15/1983
# 12   mchittockb     Myriam Chittock      1/26/1989
# 13   mfranzewitchc  Max Franzewitch      12/25/1997
# 14   aeasbyd        Alessandra Easby     1/5/1991
# 15   hschubarte     Hubert Schubart      11/23/1984
# 16   dleishmanf     Dyane Leishman       2/12/1990
# 17   scoilsg        Shayla Coils
# 18   bkrzysztofh    Bendick Krzysztof    10/19/1985
# 19   omarusiki      Otha Marusik         12/4/1992
# ...

# %%
#deleting empty rows
social_media[social_media==""] <- NA
social_media <- social_media[complete.cases(social_media), ]
social_media
# Out:
#      username       full_name            birthdate
# 4    rphettis3      Ruddy Phettis        6/18/1984
# 7    ttotman6       Tamqrah Totman       8/7/1986
# 9    kgrigoryev8    Krishna Grigoryev    5/25/1990
# 12   mchittockb     Myriam Chittock      1/26/1989
# 14   aeasbyd        Alessandra Easby     1/5/1991
# 19   omarusiki      Otha Marusik         12/4/1992
# 21   sspenclayk     Scott Spenclay       12/7/1989
# 22   gklinckl       Georgetta Klinck     7/26/1996
# 23   rhollowm       Riccardo Hollow      1/18/1980
# 30   ddimmockt      Didi Dimmock         5/15/1985
# 31   fpythonu       Franz Python         4/5/1984
# 36   amcclellandz   Annabela McClelland  8/12/1983
# 38   kpietzker11    Keane Pietzker       11/26/1996
# 39   olandreth12    Orsa Landreth        1/10/2000
# 41   clettice14     Cosette Lettice      12/23/1981
# 48   bgribbon1b     Bennie Gribbon       11/12/1984
# 50   lherley1d      Lorianne Herley      11/30/1984
# ...

# %%
#arranging by followers and showing those with the top ten
social_mediatop <- social_media1 %>%
  arrange(desc("follower")) %>%
  slice(1:10)
social_mediatop
# Out:
#    username    full_name         birthdate email                     continent
# 1  rphettis3   Ruddy Phettis     6/18/1984 rphettis3@npr.org         EU
# 2  ttotman6    Tamqrah Totman    8/7/1986  ttotman6@elpais.com       AF
# 3  kgrigoryev8 Krishna Grigoryev 5/25/1990 kgrigoryev8@quantcast.com EU
# 4  mchittockb  Myriam Chittock   1/26/1989 mchittockb@uiuc.edu       AF
# 5  aeasbyd     Alessandra Easby  1/5/1991  aeasbyd@google.ca         AF
# 6  omarusiki   Otha Marusik      12/4/1992 omarusiki@cdbaby.com      AF
# 7  sspenclayk  Scott Spenclay    12/7/1989 sspenclayk@wikispaces.com AF
# 8  gklinckl    Georgetta Klinck  7/26/1996 gklinckl@over-blog.com    SA
# 9  rhollowm    Riccardo Hollow   1/18/1980 rhollowm@dyndns.org       OC
# 10 ddimmockt   Didi Dimmock      5/15/1985 ddimmockt@wired.com       EU
#    followers last_login interests
# 1  80047     9/20/2023  travel
# 2  42669     3/10/2023  music
# 3  93923     1/30/2023  travel
# 4  46304     8/29/2023  sports
# ...

# %%
#grouping by continent
social_media1 %>%
  count(continent)
#how do i do it the non %>% way like I have done the others?
# Out:
#   continent n
# 1 AF         70
# 2 AS        111
# 3 EU         77
# 4 OC         95
# 5 SA         69
