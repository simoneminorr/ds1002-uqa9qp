# %% [markdown]
# <a href="https://colab.research.google.com/github/simoneminorr/ds1002-uqa9qp/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([56, 66, 24, 124, 47])
thelabels = ["US","UK","MX","CA","JP"]
plt.pie(y, labels = thelabels)
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)
#corrected code [NEW]
d= [d for d in range(len(n))]
plt.hist(n, bins=60)
plt.title("Histogram from Random Data")
plt.show()

# %%
#what I submitted before which was incorrect

data = n = 430 + np.random.randn(3000)
data= pd.DataFrame(data, columns=['x','y'])

for col in 'xy':
    plt.hist(data[col], alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f55a7d4af145> in <cell line: 2>()
#       1 data = n = 430 + np.random.randn(3000)
# ----> 2 data= pd.DataFrame(data, columns=['x','y'])
#       3
#       4 for col in 'xy':
#       5     plt.hist(data[col], alpha=0.5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     720                 )
#     721             else:
# --> 722                 mgr = ndarray_to_mgr(
#     723                     data,
#     724                     index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     347     )
#     348
# --> 349     _check_values_indices_shape_match(values, index, columns)
#     350
#     351     if typ == "array":
#
# ...

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

#creating trend line [NEW CODE]
m, b=np.polyfit(x,y,1)
plt.plot(x, m*x+b, color= 'pink')
plt.scatter(x, y, marker= ".", color= 'teal') #made the points dots with teal color
plt.title("Scatterplot w/ Trendline")
plt.show()

# %%
#INCORRECT OLD CODEplt.scatter(x,y)
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
