# %% [markdown]
# <a href="https://colab.research.google.com/github/simoneminorr/ds1002-uqa9qp/blob/main/practice_with_messy_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
messy= dupes = pd.read_csv('very-messy-data.csv')

# %%
messy.tail(40)
#1315 rows of data
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 1276  377           5.6          NaN           1.9          1.4        NaN
# 1277  378           4.3          3.0           1.1          3.0     setosa
# 1278  379           4.8          3.7           2.1          2.4  virginica
# 1279  380           5.8          3.2           2.4          2.6     setosa
# 1280  381           5.5          3.4           2.5          0.5     setosa
# 1281  382           4.1          3.9           1.7          2.0  virginica
# 1282  383           4.6          3.3           2.9          2.9     setosa
# 1283  384           3.7          2.6           1.1          1.0  virginica
# 1284  385           3.4          3.9           2.0          0.1     setosa
# 1285  386           3.4          3.6           1.0          0.7  virginica
# 1286  387           4.7          2.4           2.3          1.7     setosa
# ...

# %%
len(messy)
#total rows is 1316 with 1 being a header
# Out:
# 1316

# %%
messy.head
# Out:
# <bound method NDFrame.head of        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 2       3           3.8          NaN           2.2          1.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# ...   ...           ...          ...           ...          ...        ...
# 1311  412           NaN          3.6           2.9          0.5  virginica
# 1312  413           5.8          2.7           2.0          0.1  virginica
# 1313  414           3.3          3.7           1.3          2.8     setosa
# 1314  415           3.1          NaN           1.1          NaN  virginica
# 1315  416           4.3          2.5           1.3          1.0     setosa
#
# [1316 rows x 6 columns]>

# %%
messy.columns
# Out:
# Index(['id', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
messy.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1311     True
# 1312     True
# 1313     True
# 1314     True
# 1315     True
# Length: 1316, dtype: bool

# %%
print(messy.duplicated().sum())
# Out:
# 316

# %%
nomesszone = messy.drop_duplicates()
nomesszone
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 2       3           3.8          NaN           2.2          1.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# ..    ...           ...          ...           ...          ...        ...
# 995   996           4.5          3.6           NaN          2.7     setosa
# 996   997           4.0          2.1           NaN          2.1     setosa
# 997   998           5.9          2.5           2.1          2.5  virginica
# 998   999           5.0          2.6           1.9          NaN        NaN
# 999  1000           3.4          3.9           1.9          1.5     setosa
#
# [1000 rows x 6 columns]

# %%
len(nomesszone)
# Out:
# 1000

# %%
import numpy as np

# %%
dfmess= pd.DataFrame('very-messy-data.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3bd83afb5bf2> in <cell line: 1>()
# ----> 1 dfmess= pd.DataFrame('very-messy-data.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     779         else:
#     780             if index is None or columns is None:
# --> 781                 raise ValueError("DataFrame constructor not properly called!")
#     782
#     783             index = ensure_index(index)
#
# ValueError: DataFrame constructor not properly called!

# %%
minimalmess= df_miss.fillna(df_miss.median())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-21fadb4cac11> in <cell line: 1>()
# ----> 1 minimalmess= df_miss.fillna(df_miss.median())
#
# NameError: name 'df_miss' is not defined
